# %% [markdown]
# <a href="https://colab.research.google.com/github/mohamed-arif-nather/TamilNadu_District_Income_BI/blob/main/Untitled6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ##TAMIL NADU DISTRICT INCOME ESIMATES - 2011-2023

# %% [markdown]
# ![(2011-2023).png](data:image/png;base64,...)

# %% [markdown]
# ##2011-2012 Report

# %% [markdown]
# ![2011-2012.png](data:image/png;base64,...)
